# %% [markdown]
# <a href="https://colab.research.google.com/github/kerekspinney/Classification-Challenge/blob/main/student_loans_with_deep_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Student Loan Risk with Deep Learning

# %%
# Imports
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from pathlib import Path
import sklearn as skl

# %% [markdown]
# ---
#
# ## Prepare the data to be used on a neural network model

# %% [markdown]
# ### Step 1: Read the `student-loans.csv` file into a Pandas DataFrame. Review the DataFrame, looking for columns that could eventually define your features and target variables.

# %%
# Read the csv into a Pandas DataFrame
file_path = "https://static.bc-edx.com/ai/ail-v-1-0/m18/lms/datasets/student-loans.csv"
loans_df = pd.read_csv(file_path)

# Review the DataFrame
loans_df.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# 2                  0.9970            3.26              0.65
# 3                  0.9980            3.16              0.58
# 4                  0.9978            3.51              0.56
#
#    financial_aid_score  credit_ranking
# 0                  9.4               0
# 1                  9.8               0
# 2                  9.8               0
# 3                  9.8               1
# 4                  9.4               0

# %%
# Review the data types associated with the columns
loans_df.dtypes
# Out:
# payment_history           float64
# location_parameter        float64
# stem_degree_score         float64
# gpa_ranking               float64
# alumni_success            float64
# study_major_code          float64
# time_to_completion        float64
# finance_workshop_score    float64
# cohort_ranking            float64
# total_loan_score          float64
# financial_aid_score       float64
# credit_ranking              int64
# dtype: object

# %%
# Check the credit_ranking value counts
loans_df["credit_ranking"].value_counts()
# Out:
# credit_ranking
# 1    855
# 0    744
# Name: count, dtype: int64

# %% [markdown]
# ### Step 2: Using the preprocessed data, create the features (`X`) and target (`y`) datasets. The target dataset should be defined by the preprocessed DataFrame column “credit_ranking”. The remaining columns should define the features dataset.

# %%
# Define the target set y using the credit_ranking column
y = loans_df['credit_ranking']

# Display a sample of y
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 1594    0
# 1595    1
# 1596    1
# 1597    0
# 1598    1
# Name: credit_ranking, Length: 1599, dtype: int64

# %%
# Define features set X by selecting all columns but credit_ranking
X = loans_df.drop(columns='credit_ranking')

# Review the features DataFrame
X
# Out:
#       payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0                 7.4               0.700               0.00          1.9
# 1                 7.8               0.880               0.00          2.6
# 2                 7.8               0.760               0.04          2.3
# 3                11.2               0.280               0.56          1.9
# 4                 7.4               0.700               0.00          1.9
# ...               ...                 ...                ...          ...
# 1594              6.2               0.600               0.08          2.0
# 1595              5.9               0.550               0.10          2.2
# 1596              6.3               0.510               0.13          2.3
# 1597              5.9               0.645               0.12          2.0
# 1598              6.0               0.310               0.47          3.6
#
#       alumni_success  study_major_code  time_to_completion  \
# 0              0.076              11.0                34.0
# 1              0.098              25.0                67.0
# 2              0.092              15.0                54.0
# 3              0.075              17.0                60.0
# 4              0.076              11.0                34.0
# ...              ...               ...                 ...
# 1594           0.090              32.0                44.0
# 1595           0.062              39.0                51.0
# 1596           0.076              29.0                40.0
# 1597           0.075              32.0                44.0
# 1598           0.067              18.0                42.0
#
#       finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                    0.99780            3.51              0.56
# 1                    0.99680            3.20              0.68
# 2                    0.99700            3.26              0.65
# 3                    0.99800            3.16              0.58
# 4                    0.99780            3.51              0.56
# ...                      ...             ...               ...
# 1594                 0.99490            3.45              0.58
# 1595                 0.99512            3.52              0.76
# 1596                 0.99574            3.42              0.75
# 1597                 0.99547            3.57              0.71
# 1598                 0.99549            3.39              0.66
#
#       financial_aid_score
# 0                     9.4
# 1                     9.8
# 2                     9.8
# 3                     9.8
# 4                     9.4
# ...                   ...
# 1594                 10.5
# 1595                 11.2
# 1596                 11.0
# 1597                 10.2
# 1598                 11.0
#
# [1599 rows x 11 columns]

# %% [markdown]
# ### Step 3: Split the features and target sets into training and testing datasets.

# %%
# Split the preprocessed data into a training and testing dataset
# Assign the function a random_state equal to 1

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# ### Step 4: Use scikit-learn's `StandardScaler` to scale the features data.

# %%
# Create a StandardScaler instance
X_scaler = skl.preprocessing.StandardScaler()

# Fit the scaler to the features training dataset
X_scaler.fit(X_train)

# Fit the scaler to the features training dataset *I am pretty sure this is supposed to say scale the data.
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ---
#
# ## Compile and Evaluate a Model Using a Neural Network

# %% [markdown]
# ### Step 1: Create a deep neural network by assigning the number of input features, the number of layers, and the number of neurons on each layer using Tensorflow’s Keras.
#
# > **Hint** You can start with a two-layer deep neural network model that uses the `relu` activation function for both layers.

# %%
# Define the the number of inputs (features) to the model
input_nodes = len(X.columns)

# Review the number of features
len(X.columns)
# Out:
# 11

# %%
from re import S
# Define the number of hidden nodes for the first hidden layer
first_layer = tf.keras.layers.Dense(units=6, activation="relu", input_dim=input_nodes)

# Define the number of hidden nodes for the second hidden layer
second_layer = tf.keras.layers.Dense(units=3, activation="relu", input_dim=input_nodes)

# Define the number of neurons in the output layer
output_neurons = tf.keras.layers.Dense(units=1, activation="sigmoid")

# %%
# Create the Sequential model instance
nn_model = tf.keras.models.Sequential()

# Add the first hidden layer
nn_model.add(first_layer)

# Add the second hidden layer
nn_model.add(second_layer)

# Add the output layer to the model specifying the number of output neurons and activation function
nn_model.add(output_neurons)

# %%
# Display the Sequential model summary
nn_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 6)                 72
#
#  dense_7 (Dense)             (None, 3)                 21
#
#  dense_8 (Dense)             (None, 1)                 4
#
# =================================================================
# Total params: 97 (388.00 Byte)
# Trainable params: 97 (388.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Step 2: Compile and fit the model using the `binary_crossentropy` loss function, the `adam` optimizer, and the `accuracy` evaluation metric.

# %%
# Compile the Sequential model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model using 50 epochs and the training data
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 38/38 [==============================] - 1s 2ms/step - loss: 0.7001 - accuracy: 0.5154
# Epoch 2/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6840 - accuracy: 0.5388
# Epoch 3/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6725 - accuracy: 0.5680
# Epoch 4/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6614 - accuracy: 0.5796
# Epoch 5/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6500 - accuracy: 0.6097
# Epoch 6/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6380 - accuracy: 0.6380
# Epoch 7/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6244 - accuracy: 0.6547
# Epoch 8/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6095 - accuracy: 0.6956
# Epoch 9/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5960 - accuracy: 0.7006
# Epoch 10/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5840 - accuracy: 0.7106
# Epoch 11/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5733 - accuracy: 0.7064
# Epoch 12/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5634 - accuracy: 0.7056
# Epoch 13/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5561 - accuracy: 0.7123
# Epoch 14/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5499 - accuracy: 0.7089
# Epoch 15/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.7164
# Epoch 16/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5420 - accuracy: 0.7264
# Epoch 17/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5386 - accuracy: 0.7231
# Epoch 18/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5352 - accuracy: 0.7314
# Epoch 19/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5327 - accuracy: 0.7381
# Epoch 20/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5300 - accuracy: 0.7389
# Epoch 21/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5272 - accuracy: 0.7415
# Epoch 22/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5250 - accuracy: 0.7448
# Epoch 23/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5230 - accuracy: 0.7490
# Epoch 24/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5211 - accuracy: 0.7515
# Epoch 25/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5193 - accuracy: 0.7531
# Epoch 26/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5177 - accuracy: 0.7498
# Epoch 27/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5158 - accuracy: 0.7573
# Epoch 28/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5141 - accuracy: 0.7556
# Epoch 29/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5122 - accuracy: 0.7581
# Epoch 30/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5108 - accuracy: 0.7590
# Epoch 31/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5087 - accuracy: 0.7623
# Epoch 32/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5074 - accuracy: 0.7640
# Epoch 33/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5058 - accuracy: 0.7623
# Epoch 34/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5042 - accuracy: 0.7631
# Epoch 35/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5029 - accuracy: 0.7648
# Epoch 36/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5016 - accuracy: 0.7640
# Epoch 37/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5003 - accuracy: 0.7648
# Epoch 38/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.4994 - accuracy: 0.7648
# Epoch 39/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.4981 - accuracy: 0.7656
# Epoch 40/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4975 - accuracy: 0.7656
# Epoch 41/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4957 - accuracy: 0.7640
# Epoch 42/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4950 - accuracy: 0.7673
# Epoch 43/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4942 - accuracy: 0.7706
# Epoch 44/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4932 - accuracy: 0.7706
# Epoch 45/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4927 - accuracy: 0.7723
# Epoch 46/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4920 - accuracy: 0.7706
# Epoch 47/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4911 - accuracy: 0.7731
# Epoch 48/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4906 - accuracy: 0.7731
# Epoch 49/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4900 - accuracy: 0.7740
# Epoch 50/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4891 - accuracy: 0.7706

# %% [markdown]
# ### Step 3: Evaluate the model using the test data to determine the model’s loss and accuracy.

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled, y_test, verbose=2)

# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 13/13 - 0s - loss: 0.5095 - accuracy: 0.7600 - 38ms/epoch - 3ms/step
# Loss: 0.5095422863960266, Accuracy: 0.7599999904632568

# %% [markdown]
# ### Step 4: Save and export your model to a keras file, and name the file `student_loans.keras`.

# %%
# Set the model's file path


# Export your model to a keras file

# %% [markdown]
# ---
# ## Predict Loan Repayment Success by Using your Neural Network Model

# %% [markdown]
# ### Step 1: Reload your saved model.

# %%
# Set the model's file path


# Load the model to a new object

# %% [markdown]
# ### Step 2: Make predictions on the testing data and save the predictions to a DataFrame.

# %%
# Make predictions with the test data


# Display a sample of the predictions
# Out:
# 13/13 - 0s - 126ms/epoch - 10ms/step
# array([[0.63573396],
#        [0.41001907],
#        [0.88199055],
#        [0.61770827],
#        [0.9708398 ]], dtype=float32)

# %%
# Save the predictions to a DataFrame and round the predictions to binary results
# Out:
#      predictions
# 0            1.0
# 1            0.0
# 2            1.0
# 3            1.0
# 4            1.0
# ..           ...
# 395          1.0
# 396          0.0
# 397          1.0
# 398          0.0
# 399          0.0
#
# [400 rows x 1 columns]

# %% [markdown]
# ### Step 4: Display a classification report with the y test data and predictions

# %%
# Print the classification report with the y test data and predictions
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.76      0.73       188
#            1       0.77      0.72      0.74       212
#
#     accuracy                           0.73       400
#    macro avg       0.74      0.74      0.73       400
# weighted avg       0.74      0.73      0.74       400

# %% [markdown]
# ---
# ## Discuss creating a recommendation system for student loans

# %% [markdown]
# Briefly answer the following questions in the space provided:
#
# 1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.
#
# 2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.
#
# 3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.

# %% [markdown]
# **1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.**
#
#
# **2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.**
#
#
# **3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.**
